# %% [markdown]
# #Week1 Python入門

# %% [markdown]
# ##●折紙問題

# %% [markdown]
# ###【問題1】べき乗の算術演算子を使用した実装
# べき乗の算術演算子を使用したプログラムを作ってください。
# 雛形として紙を1回折った時の厚さを計算するコードを用意しました。これを43回折った時のコードに書き換えてください。

# %%
'''
《雛形》
# 紙を1回折った時の厚さを計算するコード

THICKNESS = 0.00008
folded_thickness = THICKNESS * 2
print("厚さ： {}メートル".format(folded_thickness))
'''

# 紙を43回折った時の厚さを計算するコード
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43
print("厚さ： {}メートル".format(folded_thickness))
# Out:
# 厚さ： 703687441.77664メートル

# %% [markdown]
# ###【問題2】単位の変換
# 単位がメートルだと実感が湧きづらいので、◯◯万キロメートル に変換して表示させてください。
#
#
# サンプルとして ◯◯キロメートル に変換したコードを用意したので、参考にして取り組んでください。小数点以下は2桁まで表示されるように指定しています。

# %%
'''
《サンプルコード》
# メートルをキロメートルに変換して小数点以下2桁で表示する
print("厚さ： {:.2f}キロメートル".format(folded_thickness / 1000))
'''

# メートルを○○万キロメートルに変換して小数点以下2桁で表示する
print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 1000 / 10000))
# Out:
# 厚さ： 70.37万キロメートル

# %% [markdown]
# ###【問題3】for文を使用して作成
# 次に、for文を使用したプログラムを作ってください。
#
# べき乗の算術演算子は使ってはいけません。算術演算子は四則演算（+、-、*、/）のみ使えます。

# %%
# 紙を43回折った時の厚さを計算するコード（for文）

folded_thickness = THICKNESS
for n in range(43):
  folded_thickness *= 2
print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 1000 / 10000))
# Out:
# 厚さ： 70.37万キロメートル

# %% [markdown]
# ###【問題4】計算時間の比較
# 以上の2つの方法はどちらも正しいですが、コードの良さを比較する際には例えば以下のような点で評価されます。
#
# 実行速度
# メモリの使用量
# 可読性
# 拡張性
# 再利用性

# %%
'''
《雛形》
time モジュールを用いることで時刻を取得できます。比較したい箇所の前後の時刻の差を計算することで、実行時間を求めることができます。

import time
start = time.time()
#####
# ここに比較したいコードを貼り付ける
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
'''
import time

#べき乗の算術演算子を用いたコードの実行時間 計測
start = time.time()

folded_thickness = THICKNESS * 2 ** 43
#print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 1000 / 10000))

elapsed_time = time.time() - start
print("べき乗の算術演算子を用いたコードの実行時間 : {}[s]".format(elapsed_time))


#for文を用いたコードの実行時間 計測
start = time.time()

folded_thickness = THICKNESS
for n in range(43):
  folded_thickness *= 2
#print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 1000 / 10000))

elapsed_time = time.time() - start
print("for文を用いたコードの実行時間 : {}[s]".format(elapsed_time))
# Out:
# べき乗の算術演算子を用いたコードの実行時間 : 7.128715515136719e-05[s]
# for文を用いたコードの実行時間 : 0.00012302398681640625[s]

# %% [markdown]
# ###《発展：マジックコマンドを使う》
# 実行時間は実行する度にやや変化することがあるため、複数回計測することが一般的です。time モジュールとfor文を組み合わせることでも実装できます。また、Jupyter Notebookでは%timeitという マジックコマンド でも計測できます。マジックコマンドとは標準のPythonの実行システムには用意されていない、Jupyter Notebook 特有の機能です。
#
# 実行時間を計測したいコードを書いたセルのはじめに %%timeit と入力して実行します。

# %%
# %%timeit
folded_thickness = THICKNESS * 2 ** 43
#print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 1000 / 10000))
# Out:
# The slowest run took 29.79 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000000 loops, best of 5: 83.1 ns per loop

# %%
# %%timeit
folded_thickness = THICKNESS
for n in range(43):
  folded_thickness *= 2
#print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 1000 / 10000))
# Out:
# 100000 loops, best of 5: 2.15 µs per loop

# %% [markdown]
# ###【問題5】リストへの保存
# ここまでは43回折った後の最後の値だけを使用していましたが、グラフで可視化するためには過程の値も必要です。for文を使用したコードに、過程の値合計44個を記録するコードを加えてください。
#
# 《ヒント》
#
# まず、空のリストを作成する。
# 次に、折る前の値をリストに追加する。
# for文の中でn回までの紙を折る過程の値をリストに追加していく。
#
# 最終的にリストに44個の値が格納されていることを len 関数を用いて確認しておきましょう。

# %%
thickness_values = []           #各回の紙の厚さを格納するリスト

folded_thickness = THICKNESS
thickness_values.append(folded_thickness)

for n in range(43):
  folded_thickness *= 2
  thickness_values.append(folded_thickness)
print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 1000 / 10000))
print("リストの要素数： {}".format(len(thickness_values)))
print("\n")
print("###各回の紙の厚さ###")
for n in range(len(thickness_values)):
  print("{}回目： {}メートル".format(n, thickness_values[n]))
# Out:
# 厚さ： 70.37万キロメートル
# リストの要素数： 44
#
#
# ###各回の紙の厚さ###
# 0回目： 8e-05メートル
# 1回目： 0.00016メートル
# 2回目： 0.00032メートル
# 3回目： 0.00064メートル
# 4回目： 0.00128メートル
# 5回目： 0.00256メートル
# 6回目： 0.00512メートル
# 7回目： 0.01024メートル
# 8回目： 0.02048メートル
# 9回目： 0.04096メートル
# 10回目： 0.08192メートル
# 11回目： 0.16384メートル
# 12回目： 0.32768メートル
# 13回目： 0.65536メートル
# 14回目： 1.31072メートル
# 15回目： 2.62144メートル
# 16回目： 5.24288メートル
# 17回目： 10.48576メートル
# 18回目： 20.97152メートル
# 19回目： 41.94304メートル
# 20回目： 83.88608メートル
# 21回目： 167.77216メートル
# 22回目： 335.54432メートル
# 23回目： 671.08864メートル
# 24回目： 1342.17728メートル
# 25回目： 2684.35456メートル
# 26回目： 5368.70912メートル
# 27回目： 10737.41824メートル
# 28回目： 21474.83648メートル
# 29回目： 42949.67296メートル
# 30回目： 85899.34592メートル
# 31回目： 171798.69184メートル
# 32回目： 343597.38368メートル
# 33回目： 687194.76736メートル
# 34回目： 1374389.53472メートル
# 35回目： 2748779.06944メートル
# 36回目： 5497558.13888メートル
# 37回目： 10995116.27776メートル
# 38回目： 21990232.55552メートル
# 39回目： 43980465.11104メートル
# 40回目： 87960930.22208メートル
# 41回目： 175921860.44416メートル
# ...

# %% [markdown]
# ###【問題6】折れ線グラフの表示
# グラフの描画には Matplotlib という ライブラリ を用います。リストへ記録するコードの後ろで以下の雛形を使用してください。

# %%
'''
《雛形》
import matplotlib.pyplot as plt
# %matplotlib inline
# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(リスト名)  # 「リスト名」のところにリストの変数名を入れる
plt.show()
'''

import matplotlib.pyplot as plt
# %matplotlib inline
# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(thickness_values)
plt.show()

# %% [markdown]
# ###【問題7】グラフのカスタマイズ
# グラフをより見やすくカスタマイズしてみましょう。カスタマイズしたグラフを最低3種類作成してください。例えば以下のように書き換えることで、線の色を赤に変更できます。

# %%
'''
《サンプルコード》
# 赤い折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(リスト名, color='red')
plt.show()
'''
# パターン１
matplotlib.style.use('classic')
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(thickness_values, color='red')
plt.show()

# %%
print(matplotlib.style.available)

# パターン２
matplotlib.style.use('ggplot')
plt.title("thickness of folded paper", family = 'serif', size = 30, weight ='bold')
plt.xlabel("number of folds", family = 'fantasy', size = 20, weight ='bold')
plt.ylabel("thickness [m]", family = 'cursive', size = 20, weight ='light')
plt.plot(thickness_values, color='blue', linewidth=5, linestyle="dashed")
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# パターン３
matplotlib.style.use('Solarize_Light2')
plt.title("thickness of folded paper", family = 'sans-serif', size = 30, weight ='bold')
plt.xlabel("number of folds", family = 'fantasy', size = 20, weight ='bold')
plt.ylabel("thickness [m]", family = 'cursive', size = 20, weight ='light')
plt.plot(thickness_values, color='green', linewidth=2, linestyle="dashdot")
plt.show()
