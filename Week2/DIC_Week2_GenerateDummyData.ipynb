# %% [markdown]
# #Week2 機械学習のための数学

# %% [markdown]
# ##●ダミーデータの作成

# %% [markdown]
# ###【問題1】乱数の作成
# 平均が(-3, 0)、共分散行列が以下で表される2次元正規分布による乱数を500個作成してください。
#
# [
# 1.0
# 0.8
# 0.8
# 1.0
# ]
#
# 多次元の正規分布による乱数はnp.random.multivariate_normal()を使うことで作成できます。
#
#
# numpy.random.multivariate_normal — NumPy v1.19 Manual
#
#
# 作成したndarrayのshapeは(500, 2)になります。

# %%
import numpy as np

np.random.seed(0)
mean = [-3, 0]
cov = [[1.0, 0.8], [0.8, 1.0]]

random_ndarray = np.random.multivariate_normal(mean, cov, 500)

print(random_ndarray)
print(np.shape(random_ndarray))
# Out:
# [[-4.80006782e+00 -1.54698618e+00]
#  [-4.63714503e+00 -2.19879728e-01]
#  [-4.46267867e+00 -2.08076347e+00]
#  [-3.85346966e+00 -9.49196365e-01]
#  [-3.03192065e+00  2.27764648e-01]
#  [-3.59653339e+00  3.23229932e-01]
#  [-3.76046080e+00 -6.83506760e-01]
#  [-3.52660272e+00 -3.15568548e-01]
#  [-4.35253112e+00 -1.48228460e+00]
#  [-3.02691331e+00 -5.67090887e-01]
#  [-7.84713550e-01  2.62867115e+00]
#  [-3.58538300e+00 -1.05476937e+00]
#  [-4.69336749e+00 -2.61318911e+00]
#  [-2.98421761e+00 -1.02603072e-01]
#  [-4.91877408e+00 -9.89469999e-01]
#  [-3.26658152e+00 -2.74105461e-02]
#  [-1.53138965e+00  2.15844669e-01]
#  [-2.71938344e+00  3.79500330e-01]
#  [-4.54738211e+00 -7.86930327e-01]
#  [-2.53695299e+00  2.71853959e-01]
#  [-1.55620621e+00  5.45695585e-01]
#  [-1.99817931e+00  2.23559938e+00]
#  [-2.37797023e+00  3.44967255e-01]
#  [-2.05735800e+00  1.43437007e+00]
#  [-1.40164768e+00  1.46380355e+00]
#  [-2.27283514e+00  9.71863483e-01]
#  [-2.14205902e+00  1.11243624e-01]
# ...

# %% [markdown]
# ###【問題2】散布図による可視化
# 問題1で作成したデータ点を散布図により可視化してください。
#
#
# 散布図はmatplotlibのplt.scatter()を使うことで描けます。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter")
plt.scatter(random_ndarray[:, 0], random_ndarray[:, 1])
plt.show()

# %% [markdown]
# ###【問題3】ヒストグラムによる可視化
# 問題1で作成したデータをヒストグラムにより可視化してください。
#
#
# ヒストグラムはplt.hist()を使うことで描けます。
#
#
# matplotlib.pyplot.hist — Matplotlib 3.1.1 documentation
#
#
# 各次元ごとに作成し、2つのヒストグラムとしてください。
#
#
# それぞれのヒストグラムの横軸の範囲はplt.xlim()を用いて揃えるようにしてください。

# %%
plt.xlabel("x")
plt.ylabel("frequency")
plt.title("histgram-x")
plt.hist(random_ndarray[:, 0])
plt.show()
plt.xlabel("y")
plt.ylabel("frequency")
plt.title("histgram-y")
plt.hist(random_ndarray[:, 1])
plt.show()

# %% [markdown]
# ###【問題4】データの追加
# 新たに平均が(0, -3)、共分散行列が以下で表される2次元正規分布による乱数を500個作成してください。
#
#
# [
# 1.0
# 0.8
# 0.8
# 1.0
# ]
#
# そして、問題1、4それぞれのデータをひとつの散布図として可視化してください。凡例として問題1のものは0、問題4のものは1を表示してください。

# %%
mean2 = [0, -3]
cov2 = [[1.0, 0.8], [0.8, 1.0]]

random_ndarray2 = np.random.multivariate_normal(mean2, cov2, 500)

print(random_ndarray2)
print(np.shape(random_ndarray2))

plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter")
plt.scatter(random_ndarray[:, 0], random_ndarray[:, 1], label="0")
plt.scatter(random_ndarray2[:, 0], random_ndarray2[:, 1], label="1")
plt.legend(loc='best') # 凡例を表示
plt.show()
# Out:
# [[-8.09657532e-01 -3.24520748e+00]
#  [ 3.67529537e-01 -2.56624350e+00]
#  [-2.80063934e-01 -3.15263683e+00]
#  [ 6.19037591e-02 -4.08794950e+00]
#  [-2.87961402e-02 -2.87761802e+00]
#  [ 4.19635934e-01 -1.52164254e+00]
#  [-6.47660568e-01 -2.65887659e+00]
#  [ 1.03686948e+00 -2.53695750e+00]
#  [ 3.18103534e-01 -3.74359221e+00]
#  [-2.34677686e-01 -3.17319084e+00]
#  [-1.18523343e+00 -3.74185595e+00]
#  [ 7.43112704e-01 -2.95100513e+00]
#  [-1.37394660e+00 -4.87492413e+00]
#  [ 1.33493329e+00 -2.35118992e+00]
#  [-8.95878239e-01 -4.22405954e+00]
#  [ 6.71485493e-01 -2.24143182e+00]
#  [ 4.10757603e-01 -3.01810762e+00]
#  [-1.05218145e+00 -3.37841677e+00]
#  [-1.17727556e+00 -3.69223297e+00]
#  [ 1.79620978e-01 -3.94354921e+00]
#  [-1.67908773e+00 -4.48809299e+00]
#  [-9.29529890e-01 -3.22436580e+00]
#  [-1.49210665e+00 -4.22748851e+00]
#  [-2.23704012e-01 -3.60268672e+00]
#  [ 2.38717813e-01 -3.30150120e+00]
#  [ 9.65568595e-01 -2.59957748e+00]
#  [-1.83735136e-01 -2.52023035e+00]
# ...

# %% [markdown]
# ###【問題5】データの結合
# データはまとめておいた方が後々扱いやすいです。問題1、4で作成したndarrayを 結合 し、(1000, 2)のndarrayとしてください。結合はnp.concatenate()やnp.vstack()を使うことで行えます。
#
#
# numpy.concatenate — NumPy v1.19 Manual
#
#
# numpy.vstack — NumPy v1.19 Manual

# %%
random_ndarray3 = np.concatenate([random_ndarray, random_ndarray2])
print(random_ndarray3)
print(random_ndarray3.shape)
# Out:
# [[-4.80006782 -1.54698618]
#  [-4.63714503 -0.21987973]
#  [-4.46267867 -2.08076347]
#  ...
#  [-0.2185878  -3.15676476]
#  [-1.37970304 -4.27950068]
#  [ 1.49786804 -2.33126243]]
# (1000, 2)

# %% [markdown]
# ###【問題6】ラベル付け
# ひとまとめになった1000個のデータそれぞれに対して、問題1、4どちらで作成したものなのかを示す ラベル 付けを行ってください。問題1のものには0、問題4のものには1を対応させます。
#
#
# 0と1を含むラベルの列を新たに追加し、(1000, 3)のndarrayを作成してください。
#
#
# 機械学習に使用するデータセットはこのような形になっていることが多いです。

# %%
zero_ndarray = np.zeros((500, 1))
one_ndarray = np.ones((500, 1))

random_ndarray4 = np.concatenate([zero_ndarray, one_ndarray])

random_ndarray5 = np.concatenate([random_ndarray3, random_ndarray4], axis = 1)
print(random_ndarray5)
print(random_ndarray5.shape)
# Out:
# [[-4.80006782 -1.54698618  0.        ]
#  [-4.63714503 -0.21987973  0.        ]
#  [-4.46267867 -2.08076347  0.        ]
#  ...
#  [-0.2185878  -3.15676476  1.        ]
#  [-1.37970304 -4.27950068  1.        ]
#  [ 1.49786804 -2.33126243  1.        ]]
# (1000, 3)
